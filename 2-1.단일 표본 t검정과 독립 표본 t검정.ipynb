# %% [markdown]
# # 단일 표본 t 검정
#
# - txt 파일의 데이터를 읽어서 float형으로 형변환
# - 정규성 검정
#     - kstest를 활용해 정규성 검정 진행
# - 단일표본 t 검정
#     - p-value < 0.05 : 귀무가설 기각, 대립가설 채택, 통계적으로 유의미하다.
#     - p-value > 0.05 : 귀무가설 채택, 대립가설 기각

# %% [markdown]
# ## 정규성 검정

# %%
with open("datas2/성인여성_키_데이터.txt", "r", encoding="utf8") as f:
    data = f.read().split('\n')
    # print(data)
    data = list(map(float, data))
    print(data)
# Out:
# [150.27, 142.94, 160.99, 157.48, 153.46, 137.5, 154.94, 159.51, 171.87, 143.69, 153.65, 160.25, 153.07, 154.42, 141.21, 154.17, 162.56, 164.44, 172.36, 141.51, 169.4, 167.97, 170.26, 157.8, 167.61]

# %%
from scipy import stats
import numpy as np

# 평균과 표준편차 계산
mean_value = np.mean(data)
std_dev = np.std(data, ddof=0)  # 모집단 표준편차(기본 설정)

mean_value, std_dev
# Out:
# (np.float64(156.9332), np.float64(9.974187774450611))

# %% [markdown]
# ## 가설 설정
# - 귀무가설: 표본 데이터의 평균은 163과 같다.
# - 대립가설: 표본 데이터의 평균은 163과 다르다.

# %% [markdown]
# ## 정규성 검정
# - 방법1: KS-test

# %%
#  KS-test는 주어진 표본 데이터가 정규분포를 따르는지 검정한다.

# 'norm': 비교 대상이 되는 이론적인 분포를 지정 ('norm'은 정규분포)
# args=(np.mean(data), np.std(data, ddof=0)): 표본 데이터의 평균과 표준편차를 사용하여 정규분포의 모수 설정
ks_statistic, p_value = stats.kstest(data, 'norm', args=(np.mean(data), np.std(data, ddof=0)))
ks_statistic, p_value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       1 #  KS-test는 주어진 표본 데이터가 특정 이론적인 분포(예: 정규분포)를 따르는지 검정한다.
#       2
#       3 # 'norm': 비교 대상이 되는 이론적인 분포를 지정 ('norm'은 정규분포)
#       4 # args=(np.mean(data), np.std(data, ddof=0)): 표본 데이터의 평균과 표준편차를 사용하여 정규분포의 모수 설정
# ----> 5 ks_statistic, p_value = stats.kstest(data, 'norm', args=(np.mean(data), np.std(data, ddof=0)))
#       6 ks_statistic, p_value
#
# File ~/statistics_ex/.venv/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:601, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     598     res = _add_reduced_axes(res, reduced_axes, keepdims)
#     599     return tuple_to_result(*res)
# --> 601 res = hypotest_fun_out(*samples, **kwds)
#     602 res = result_to_tuple(res, n_out)
#     603 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File ~/statistics_ex/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:880, in _rename_parameter.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     878         raise TypeError(message)
#     879     kwargs[new_name] = kwargs.pop(old_name)
# --> 880 return fun(*args, **kwargs)
#
# File ~/statistics_ex/.venv/lib/python3.12/site-packages/scipy/stats/_stats_py.py:8413, in kstest(rvs, cdf, args, N, alternative, method, axis)
#    8409     if alternative not in ['two-sided', 'greater', 'less']:
#    8410         raise ValueError(f"Unexpected alternative: {alternative}")
#    8411     xvals, yvals, cdf = _parse_kstest_args(rvs, cdf, args, N)
#    8412     if cdf:
# -> 8413         return ks_1samp(xvals, cdf, args=args, alternative=alternative,
#    8414                         method=method, axis=axis, _no_deco=True)
#    8415     return ks_2samp(xvals, yvals, alternative=alternative, method=method,
#    8416                     axis=axis, _no_deco=True)
#
# File ~/statistics_ex/.venv/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:431, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(_no_deco, *args, **kwds)
#     427 @wraps(hypotest_fun_in)
#     428 def axis_nan_policy_wrapper(*args, _no_deco=False, **kwds):
#     430     if _no_deco:  # for testing, decorator does nothing
# --> 431         return hypotest_fun_in(*args, **kwds)
#     433     # For now, skip the decorator entirely if using array API. In the future,
#     434     # we'll probably want to use it for `keepdims`, `axis` tuples, etc.
#     435     if len(args) == 0:  # extract sample from `kwds` if there are no `args`
#
# File ~/statistics_ex/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:880, in _rename_parameter.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     878         raise TypeError(message)
#     879     kwargs[new_name] = kwargs.pop(old_name)
# --> 880 return fun(*args, **kwargs)
#
# File ~/statistics_ex/.venv/lib/python3.12/site-packages/scipy/stats/_stats_py.py:7660, in ks_1samp(x, cdf, args, alternative, method, axis)
#    7656
#    7657     x = xp.sort(x, axis=-1)
#    7658     x = xp_promote(x, force_floating=True, xp=xp)
#    7659     N = _count_nonmasked(x, axis=-1, xp=xp)
# -> 7660     cdfvals = _masked_apply(cdf, args=(x, *args), xp=xp)
#    7661
#    7662     ones = xp.ones(x.shape[:-1], dtype=xp.int8)
#    7663     ones = ones[()] if ones.ndim == 0 else ones
#
# File ~/statistics_ex/.venv/lib/python3.12/site-packages/scipy/_lib/_array_api.py:695, in _masked_apply(f, args, kwargs, xp)
#     692 kwargs = {} if kwargs is None else kwargs
#     694 if not is_marray(xp):
# --> 695     return f(*args, **kwargs)
#     697 arg_data = (getattr(arg, 'data', arg) for arg in args)
#     698 kwarg_data = (getattr(val, 'data', val) for val in kwargs.values())
#
# TypeError: ndtr() takes from 1 to 2 positional arguments but 3 were given
